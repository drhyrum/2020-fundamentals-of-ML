# %%
# %matplotlib notebook
from sklearn.tree import DecisionTreeClassifier, plot_tree
import pandas as pd

# %%
data = pd.read_csv('../../data/20questions/micro.csv')

# %%
display(data)
# Out:
#   Unnamed: 0  is it aquatic?  does it lay eggs?  does it have 4 legs?  \
# 0    giraffe               0                  0                     1
# 1       seal               1                  0                     0
# 2    chicken               0                  1                     0
# 3    penguin               1                  1                     0
# 4   elephant               0                  0                     1
#
#    does it have a trunk?  does it have 2 legs?
# 0                      0                     0
# 1                      0                     0
# 2                      0                     1
# 3                      0                     1
# 4                      1                     0

# %%
target = data[data.columns[0]]
feature_names = data.columns[1:]
features = data[feature_names]

# %%
model = DecisionTreeClassifier().fit(features, target)

# %%
from IPython.display import display
plot_tree(model, feature_names=feature_names, class_names=model.classes_, impurity=False, node_ids=False, label='none', filled=True, fontsize=8)
# Out:
# <img src="data:image/png;base64,..." width="640">
# [Text(248.0, 323.4, 'does it have 4 legs? <= 0.5\n5\n[1, 1, 1, 1, 1]\nchicken'),
#  Text(124.0, 230.99999999999997, 'does it have 2 legs? <= 0.5\n3\n[1, 0, 0, 1, 1]\nchicken'),
#  Text(62.0, 138.6, '1\n[0, 0, 0, 0, 1]\nseal'),
#  Text(186.0, 138.6, 'is it aquatic? <= 0.5\n2\n[1, 0, 0, 1, 0]\nchicken'),
#  Text(124.0, 46.19999999999999, '1\n[1, 0, 0, 0, 0]\nchicken'),
#  Text(248.0, 46.19999999999999, '1\n[0, 0, 0, 1, 0]\npenguin'),
#  Text(372.0, 230.99999999999997, 'does it have a trunk? <= 0.5\n2\n[0, 1, 1, 0, 0]\nelephant'),
#  Text(310.0, 138.6, '1\n[0, 0, 1, 0, 0]\ngiraffe'),
#  Text(434.0, 138.6, '1\n[0, 1, 0, 0, 0]\nelephant')]

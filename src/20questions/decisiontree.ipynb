# %%
# %matplotlib inline
from sklearn.tree import DecisionTreeClassifier, plot_tree
import pandas as pd

# %%
data = pd.read_csv('../../data/20questions/micro.csv')

# %%
display(data)
# Out:
#   Unnamed: 0  is it aquatic?  does it lay eggs?  does it have 4 legs?  \
# 0    giraffe               0                  0                     1
# 1       seal               1                  0                     0
# 2    chicken               0                  1                     0
# 3    penguin               1                  1                     0
# 4   elephant               0                  0                     1
#
#    does it have a trunk?  does it have 2 legs?
# 0                      0                     0
# 1                      0                     0
# 2                      0                     1
# 3                      0                     1
# 4                      1                     0

# %%
target = data[data.columns[0]]
feature_names = data.columns[1:]
features = data[feature_names]

# %%
model = DecisionTreeClassifier().fit(features, target)

# %%
plot_tree(model, feature_names=feature_names, class_names=model.classes_, impurity=False, node_ids=False, label='none', filled=True, fontsize=8)
# Out:
# [Text(186.0, 190.26, 'is it aquatic? <= 0.5\n5\n[1, 1, 1, 1, 1]\nchicken'),
#  Text(111.60000000000001, 135.9, 'does it have 2 legs? <= 0.5\n3\n[1, 1, 1, 0, 0]\nchicken'),
#  Text(74.4, 81.53999999999999, 'does it have a trunk? <= 0.5\n2\n[0, 1, 1, 0, 0]\nelephant'),
#  Text(37.2, 27.180000000000007, '1\n[0, 0, 1, 0, 0]\ngiraffe'),
#  Text(111.60000000000001, 27.180000000000007, '1\n[0, 1, 0, 0, 0]\nelephant'),
#  Text(148.8, 81.53999999999999, '1\n[1, 0, 0, 0, 0]\nchicken'),
#  Text(260.40000000000003, 135.9, 'does it lay eggs? <= 0.5\n2\n[0, 0, 0, 1, 1]\npenguin'),
#  Text(223.20000000000002, 81.53999999999999, '1\n[0, 0, 0, 0, 1]\nseal'),
#  Text(297.6, 81.53999999999999, '1\n[0, 0, 0, 1, 0]\npenguin')]
